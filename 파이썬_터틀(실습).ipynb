# %% [markdown]
# <a href="https://colab.research.google.com/github/lwb1601/python_data/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%ED%84%B0%ED%8B%80(%EC%8B%A4%EC%8A%B5).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 터틀 프로그램 설치

# %%
# !pip3 install ColabTurtle
from ColabTurtle.Turtle import *

# %% [markdown]
# # 따라해 보기

# %%
initializeTurtle() #그래픽 초기화
speed(1) #그래픽 그려지는 속도 제어
forward(50)
forward(50)
forward(50)
forward(50)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="200.0" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="150.0" x2="400.0" y2="100.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="100.0" x2="400.0" y2="50.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#
#       <g visibility=visible transform="rotate(180,400.0,50.0) translate(400.0, 50.0)">
#         <circle stroke="white" stroke-width="3" fill="transparent" r="12" cx="0" cy="0"/>
#         <polygon points="0,19 3,16 -3,16" style="fill:white;stroke:white;stroke-width:2"/>
#       </g>
#
#       </svg>

# %%
# 따라해보기
speed(1)
forward(50)
right(90)
forward(50)
right(90)
forward(50)
right(90)
forward(50)
right(90)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="200.0" x2="450.0" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="450.0" y1="200.0" x2="450.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="450.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#
#       <g visibility=visible transform="rotate(180,400.0,250.0) translate(400.0, 250.0)">
#         <circle stroke="white" stroke-width="3" fill="transparent" r="12" cx="0" cy="0"/>
#         <polygon points="0,19 3,16 -3,16" style="fill:white;stroke:white;stroke-width:2"/>
#       </g>
#
#       </svg>

# %% [markdown]
# ## forword(num) 와 right(num) 의 의미는 무엇일까요?

# %% [markdown]
# # 연습문제1
# 변의 길이가 100인 정삼각형 그리기

# %%
initializeTurtle()
speed(3)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="150.0" x2="313.3974596215561" y2="200.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="313.3974596215561" y1="200.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#
#       <g visibility=visible transform="rotate(180,400.0,250.0) translate(400.0, 250.0)">
#         <circle stroke="white" stroke-width="3" fill="transparent" r="12" cx="0" cy="0"/>
#         <polygon points="0,19 3,16 -3,16" style="fill:white;stroke:white;stroke-width:2"/>
#       </g>
#
#       </svg>

# %% [markdown]
# #연습문제2
# 변의 길이가 100인 정육각형 그리기
#
# 정육각형의 내각의 합은 720도

# %%
initializeTurtle()
speed(3)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="400.0" y1="150.0" x2="313.39745962155615" y2="99.99999999999999" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="313.39745962155615" y1="99.99999999999999" x2="226.79491924311228" y2="149.99999999999997" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="226.79491924311228" y1="149.99999999999997" x2="226.79491924311228" y2="249.99999999999997" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="226.79491924311228" y1="249.99999999999997" x2="313.39745962155615" y2="299.99999999999994" stroke-linecap="round" style="stroke:white;stroke-width:4"/><line x1="313.39745962155615" y1="299.99999999999994" x2="400.0" y2="249.9999999999999" stroke-linecap="round" style="stroke:white;stroke-width:4"/>
#
# ...

# %% [markdown]
# #연습문제3
# 정 삼각형으로 이루어진 단풍잎 만들기
# ![스크린샷 2020-11-13 오후 10.18.04.png](data:image/png;base64,...)
